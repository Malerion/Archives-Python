# %% [markdown]
# # Mission 1

# %% [markdown]
# Create a function that returns the sum of 3 + 3 when executed.
# You must use the `return` statement.

# %%
def trois_plus_trois():
 resultat = 3+3
 return resultat

trois_plus_trois()
# Out:
# 6

# %% [markdown]
# # Mission 2

# %% [markdown]
# Create a function that returns the sum of two numbers.
# The user of the function must be able to sum two numbers of his choice, when the function is executed.
# You must not use `input`.

# %%
def add_numbers(num1,num2):
  result = num1 + num2
  return result

#pour donner à la fonction n'importe quel chiffre deux fois. l'utilisateur entre deux chiffres dans les ()
add_numbers(12,13)
# Out:
# 25

# %% [markdown]
# Question:
# What is a parameter in a function?

# %% [markdown]
# Answer:  a parameter in a function is a variable that is used to receive input data or arguments when the function is called. Parameters act as placeholders or containers within the function and allow you to pass values into the function from the outside. These values can then be used and manipulated within the function's code.

# %% [markdown]
# # Mission 3

# %% [markdown]
# Create a function that returns the sum of two numbers chosen by the user of the function, in a sentence.
# For example:
# `new_sum_2(3,8)` returns `"The sum of 3 + 8 is equal to 11."`

# %%
def new_sum_2(num1,num2):
  result = "the sum of {} + {} is equal to {}".format(num1,num2,num1+num2)
  return result

new_sum_2(3,7)
# Out:
# 'the sum of 3 + 7 is equal to 10'

# %% [markdown]
# # Mission 4
#
# Create a function that returns 2 objects when executed:
# * An object that will be the product of two numbers chosen by the user of the function.
# * A word chosen by the user of the function.

# %%
def exec_objs(num1,num2,word):

  product = num1 * num2
  return [product, word]

exec_objs(5,10,"Space Marines")
# Out:
# [50, 'Space Marines']

# %% [markdown]
# Your result must be two objects that are in brackets.
# This is a tuple.
#
# Question:
# Why is the returned object a tuple that contains two objects?
#
# Answer:  The returned object is a tuple that contains two objects because that's how it was explicitly defined within the exec_objs function.using parentheses ( ) to create a tuple containing two objects: product and word. This is why the function returns a tuple with these two objects.

# %% [markdown]
# # Mission 5
#
# Create a function that returns the sum of two numbers when executed.
# Also, your function must return a sentence that simply indicates if the sum of the two numbers chosen by the user is:
# * less than 10
# * between 10 and 50
# * greater than 50
# Again, you must use `return`.

# %%
def sum_and_range(num1,num2):
  result = num1 + num2

  if result <10:
    return"The sum of {} and {} is {}. It is less than 10.".format(num1,num2,result)
  elif 10 <= result <= 50:
    return"The sum of {} and {} is {}. It is between 10 and 50.".format(num1,num2,result)
  else:
    return"The sum of {} and {} is {. It is greater than 50}".format(num1,num2,result)

sum_and_range(10,30)
# Out:
# 'The sum of 10 and 30 is 40. It is between 10 and 50.'
