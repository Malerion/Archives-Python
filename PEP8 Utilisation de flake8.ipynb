# %%
# !pip install flake8
# Out:
# Requirement already satisfied: flake8 in /usr/local/lib/python3.10/dist-packages (6.1.0)
# Requirement already satisfied: mccabe<0.8.0,>=0.7.0 in /usr/local/lib/python3.10/dist-packages (from flake8) (0.7.0)
# Requirement already satisfied: pycodestyle<2.12.0,>=2.11.0 in /usr/local/lib/python3.10/dist-packages (from flake8) (2.11.0)
# Requirement already satisfied: pyflakes<3.2.0,>=3.1.0 in /usr/local/lib/python3.10/dist-packages (from flake8) (3.1.0)

# %%
def perform_operations(num1, num2, num3):
    try:
        add_result = (num1 + num2) / num3

        if add_result > 0:
            result_message = "Positive result"
        elif add_result < 0:
            result_message = "Negative result"
        else:
            result_message = "Zero result"

        return result_message, add_result
    except ZeroDivisionError:
        error_message = "Error: Division by zero is not allowed."
        return error_message


perform_operations(80, 40,0)
# Out:
# 'Error: Division by zero is not allowed.'

# %%
# %%writefile mon_test.py

def perform_operations(num1, num2, num3):
    try:
        add_result = (num1 + num2) / num3

        if add_result > 0:
            result_message = "Positive result"
        elif add_result < 0:
            result_message = "Negative result"
        else:
            result_message = "Zero result"

        return result_message, add_result
    except ZeroDivisionError:
        error_message = "Error: Division by zero is not allowed."
        return error_message


perform_operations(80, 40,0)
# Out:
# Overwriting mon_test.py

# %%
# !flake8 mon_test.py
# Out:
# mon_test.py:19:26: E231 missing whitespace after ','

# %%
def perform_operations(num1, num2, num3):
    try:
        add_result = (num1 + num2) / num3

        if add_result > 0:
            result_message = "Positive result"
        elif add_result < 0:
            result_message = "Negative result"
        else:
            result_message = "Zero result"

        return result_message, add_result
    except ZeroDivisionError:
        error_message = "Error: Division by zero is not allowed."
        return error_message


perform_operations(80, 40, 0)
# Out:
# 'Error: Division by zero is not allowed.'

# %%
# %%writefile mon_test2.py

def perform_operations(num1, num2, num3):
    try:
        add_result = (num1 + num2) / num3

        if add_result > 0:
            result_message = "Positive result"
        elif add_result < 0:
            result_message = "Negative result"
        else:
            result_message = "Zero result"

        return result_message, add_result
    except ZeroDivisionError:
        error_message = "Error: Division by zero is not allowed."
        return error_message


perform_operations(80, 40, 0)
# Out:
# Writing mon_test2.py

# %%
# !flake8 mon_test2.py
# Out:
# /bin/bash: line 1: flake8: command not found
